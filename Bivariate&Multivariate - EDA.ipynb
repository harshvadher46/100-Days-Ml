# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1 = sns.load_dataset('iris')

# %%
df2 = sns.load_dataset('titanic')

# %%
df3 = sns.load_dataset('flights')

# %% [markdown]
# ## Scatter Plot(Numerical- Numerical)

# %%
sns.scatterplot(df,x='total_bill',y='tip',hue='sex',style='smoker',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Bar plot (Numerical - Categorical)

# %%
# it show that the category vise age group mostly travel
sns.barplot(df2,x='pclass',y='age',hue='sex')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.barplot(df2,x='pclass',y='fare',hue='sex')
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %% [markdown]
# ## Boxplot(Numerical - Categorical)

# %%
sns.boxplot(df2,x='sex',y='age',hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# ## Distplot(Numerical - Categorical)

# %%
sns.distplot(df2,x='')
# Out:
# C:\Users\Art\AppData\Local\Temp\ipykernel_3548\2874239602.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2,x='age')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 sns.distplot(df2,x='age')
#
# File D:\Anaconda\Lib\site-packages\seaborn\distributions.py:2458, in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2455     a = x
#    2457 # Make a a 1-d float array
# -> 2458 a = np.asarray(a, float)
# ...

# %% [markdown]
# ## Heatmap(Categorical - Categorical)

# %%
sns.heatmap(pd.crosstab(df2['pclass'],df2['survived']))
# The lighter(cream shade shows that the number of people in class 3 were died the most)
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %%
(df2.groupby('pclass').mean()['survived']*100).plot(kind='bar')
# Out:
# C:\Users\Art\AppData\Local\Temp\ipykernel_3548\2871550289.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   (df2.groupby('pclass').mean()['survived']*100).plot(kind='bar')
# <Axes: xlabel='pclass'>

# %%
df2.groupby('sex').mean()['survived']*100
# Out:
# C:\Users\Art\AppData\Local\Temp\ipykernel_3548\2345857457.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2.groupby('sex').mean()['survived']*100
# sex
# female    74.203822
# male      18.890815
# Name: survived, dtype: float64

# %%
# df2.groupby('embarked').mean()['survived'].plot
# sns.(df2,x='embarked',y='sex')

# %% [markdown]
# ## ClusterMap(Categorical-categorical)

# %%
sns.clustermap(pd.crosstab(df2['parch'],df2['survived'])) # The side bar shows that the connected ones are highly related to each other

# %% [markdown]
# ### Pair plot

# %%
# it shows all the relationship of all the (NUMERICAL) columns with each other using the scatter plot
sns.pairplot(df1,hue='species')

# %% [markdown]
# ## LinePlot(Numerical-Numerical)

# %%
new = df3.groupby('year').sum().reset_index()
# Out:
# C:\Users\Art\AppData\Local\Temp\ipykernel_3548\1662787889.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new = df3.groupby('year').sum().reset_index()

# %%
new
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
sns.lineplot(new,x='passengers',y='year') # Here you can clearly see that the number of customer grows as the year increases
# Out:
# <Axes: xlabel='passengers', ylabel='year'>

# %%
# histogram works well with huge amount of data 
df3.pivot_table(values='passengers',index='month',columns='year')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(df3.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# <Axes: xlabel='year', ylabel='month'>
